# %% [markdown]
# # **3 Layer Network on EMNIST**

# %%
import sys, numpy as np
import pandas as pd

train = pd.read_csv("./input/emnist-balanced-train.csv",delimiter = ',')
test = pd.read_csv("./input/emnist-balanced-test.csv", delimiter = ',')
mapp = pd.read_csv("./input/emnist-balanced-mapping.txt", delimiter = ' ', \
                   index_col=0, header=None, squeeze=True)

# Constants
HEIGHT = 28
WIDTH = 28

# Split x and y
train_x = train.iloc[:1000,1:]
train_y = train.iloc[:1000,0]
del train

test_x = test.iloc[:1000,1:]
test_y = test.iloc[:1000,0]
del test

def rotate(image):
    image = image.reshape([HEIGHT, WIDTH])
    image = np.fliplr(image)
    image = np.rot90(image)
    return image

# Flip and rotate image
train_x = np.asarray(train_x)
train_x = np.apply_along_axis(rotate, 1, train_x)
test_x = np.asarray(test_x)
test_x = np.apply_along_axis(rotate, 1, test_x)

# Normalise
train_x = train_x.astype('float32')
train_x /= 255
test_x = test_x.astype('float32')
test_x /= 255

#reshape rotated images again
images = train_x.reshape(1000,28*28)
labels = train_y

one_hot_labels = np.zeros((len(labels), 47))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = test_x.reshape(len(test_x),28*28)
test_labels = np.zeros((len(test_y), 47))
for i,l in enumerate(test_y):
    test_labels[i][l] = 1

np.random.seed(1)
relu = lambda x:(x>=0) * x # returns x if x > 0, return 0 otherwise
relu2deriv = lambda x: x>=0 # returns 1 for input > 0, return 0 otherwise
alpha, iterations, hidden_size, pixels_per_image, num_labels = (0.005, 750, 40, 784, 47)

weights_0_1 = 0.2*np.random.random((pixels_per_image,hidden_size)) - 0.1
weights_1_2 = 0.2*np.random.random((hidden_size,num_labels)) - 0.1

for j in range(iterations):
    error, correct_cnt = (0.0, 0)
    
    for i in range(len(images)):
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0,weights_0_1))
        layer_2 = np.dot(layer_1,weights_1_2)

        error += np.sum((labels[i:i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == \
                                        np.argmax(labels[i:i+1]))

        layer_2_delta = (labels[i:i+1] - layer_2)
        layer_1_delta = layer_2_delta.dot(weights_1_2.T)\
                                    * relu2deriv(layer_1)
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)

    sys.stdout.write("\r I:"+str(j)+ \
                     " Train-Err:" + str(error/float(len(images)))[0:5] +\
                     " Train-Acc:" + str(correct_cnt/float(len(images))))
# Out:
#  I:749 Train-Err:0.432 Train-Acc:0.726

# %%
if(j % 10 == 0 or j == iterations-1):
    error, correct_cnt = (0.0, 0)

    for i in range(len(test_images)):

        layer_0 = test_images[i:i+1]
        layer_1 = relu(np.dot(layer_0,weights_0_1))
        layer_2 = np.dot(layer_1,weights_1_2)

        error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == \
                                        np.argmax(test_labels[i:i+1]))
    sys.stdout.write(" Test-Err:" + str(error/float(len(test_images)))[0:5] +\
                     " Test-Acc:" + str(correct_cnt/float(len(test_images))) + "\n")
    print()
# Out:
#  Test-Err:4.511 Test-Acc:0.187

# %%
import sys, numpy as np

train = pd.read_csv("./input/emnist-balanced-train.csv",delimiter = ',')
test = pd.read_csv("./input/emnist-balanced-test.csv", delimiter = ',')
mapp = pd.read_csv("./input/emnist-balanced-mapping.txt", delimiter = ' ', \
                   index_col=0, header=None, squeeze=True)

# Constants
HEIGHT = 28
WIDTH = 28

# Split x and y
train_x = train.iloc[:1000,1:]
train_y = train.iloc[:1000,0]
del train

test_x = test.iloc[:1000,1:]
test_y = test.iloc[:1000,0]
del test

def rotate(image):
    image = image.reshape([HEIGHT, WIDTH])
    image = np.fliplr(image)
    image = np.rot90(image)
    return image

# Flip and rotate image
train_x = np.asarray(train_x)
train_x = np.apply_along_axis(rotate, 1, train_x)
test_x = np.asarray(test_x)
test_x = np.apply_along_axis(rotate, 1, test_x)

# Normalise
train_x = train_x.astype('float32')
train_x /= 255
test_x = test_x.astype('float32')
test_x /= 255

#reshape rotated images again
images = train_x.reshape(1000,28*28)
labels = train_y

one_hot_labels = np.zeros((len(labels), 47))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = test_x.reshape(len(test_x),28*28)
test_labels = np.zeros((len(test_y), 47))
for i,l in enumerate(test_y):
    test_labels[i][l] = 1


np.random.seed(1)
relu = lambda x:(x>=0) * x # returns x if x > 0, return 0 otherwise
relu2deriv = lambda x: x>=0 # returns 1 for input > 0, return 0 otherwise
alpha, iterations, hidden_size, pixels_per_image, num_labels = (0.005, 750, 40, 784, 47)

weights_0_1 = 0.2*np.random.random((pixels_per_image,hidden_size)) - 0.1
weights_1_2 = 0.2*np.random.random((hidden_size,num_labels)) - 0.1

for j in range(iterations):
    error, correct_cnt = (0.0, 0)
    
    for i in range(len(images)):
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0,weights_0_1))
        layer_2 = np.dot(layer_1,weights_1_2)

        error += np.sum((labels[i:i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == \
                                        np.argmax(labels[i:i+1]))

        layer_2_delta = (labels[i:i+1] - layer_2)
        layer_1_delta = layer_2_delta.dot(weights_1_2.T)\
                                    * relu2deriv(layer_1)
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)

    sys.stdout.write("\r I:"+str(j)+ \
                     " Train-Err:" + str(error/float(len(images)))[0:5] +\
                     " Train-Acc:" + str(correct_cnt/float(len(images))))
    
    if(j % 10 == 0 or j == iterations-1):
        error, correct_cnt = (0.0, 0)

        for i in range(len(test_images)):

            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0,weights_0_1))
            layer_2 = np.dot(layer_1,weights_1_2)

            error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
            correct_cnt += int(np.argmax(layer_2) == \
                                            np.argmax(test_labels[i:i+1]))
        sys.stdout.write(" Test-Err:" + str(error/float(len(test_images)))[0:5] +\
                         " Test-Acc:" + str(correct_cnt/float(len(test_images))))
        print()
# Out:
#  I:0 Train-Err:1.136 Train-Acc:0.078 Test-Err:1.035 Test-Acc:0.129
#  I:10 Train-Err:0.817 Train-Acc:0.466 Test-Err:0.890 Test-Acc:0.317
#  I:20 Train-Err:0.757 Train-Acc:0.504 Test-Err:0.868 Test-Acc:0.337
#  I:30 Train-Err:0.729 Train-Acc:0.509 Test-Err:0.870 Test-Acc:0.331
#  I:40 Train-Err:0.707 Train-Acc:0.531 Test-Err:0.877 Test-Acc:0.326
#  I:50 Train-Err:0.696 Train-Acc:0.544 Test-Err:0.886 Test-Acc:0.323
#  I:60 Train-Err:0.685 Train-Acc:0.555 Test-Err:0.895 Test-Acc:0.318
#  I:70 Train-Err:0.675 Train-Acc:0.564 Test-Err:0.906 Test-Acc:0.306
#  I:80 Train-Err:0.662 Train-Acc:0.585 Test-Err:0.920 Test-Acc:0.315
#  I:90 Train-Err:0.652 Train-Acc:0.584 Test-Err:0.935 Test-Acc:0.312
#  I:100 Train-Err:0.645 Train-Acc:0.589 Test-Err:0.949 Test-Acc:0.308
#  I:110 Train-Err:0.637 Train-Acc:0.59 Test-Err:0.959 Test-Acc:0.299
#  I:120 Train-Err:0.627 Train-Acc:0.588 Test-Err:0.969 Test-Acc:0.287
#  I:130 Train-Err:0.618 Train-Acc:0.594 Test-Err:0.981 Test-Acc:0.28
#  I:140 Train-Err:0.608 Train-Acc:0.611 Test-Err:0.995 Test-Acc:0.275
#  I:150 Train-Err:0.600 Train-Acc:0.609 Test-Err:1.009 Test-Acc:0.275
#  I:160 Train-Err:0.592 Train-Acc:0.611 Test-Err:1.023 Test-Acc:0.271
#  I:170 Train-Err:0.584 Train-Acc:0.618 Test-Err:1.036 Test-Acc:0.263
#  I:180 Train-Err:0.576 Train-Acc:0.623 Test-Err:1.048 Test-Acc:0.26
#  I:190 Train-Err:0.568 Train-Acc:0.63 Test-Err:1.061 Test-Acc:0.265
#  I:200 Train-Err:0.561 Train-Acc:0.636 Test-Err:1.073 Test-Acc:0.262
#  I:210 Train-Err:0.556 Train-Acc:0.637 Test-Err:1.084 Test-Acc:0.261
#  I:220 Train-Err:0.550 Train-Acc:0.64 Test-Err:1.097 Test-Acc:0.264
#  I:230 Train-Err:0.544 Train-Acc:0.65 Test-Err:1.110 Test-Acc:0.261
#  I:240 Train-Err:0.540 Train-Acc:0.651 Test-Err:1.127 Test-Acc:0.261
#  I:250 Train-Err:0.536 Train-Acc:0.654 Test-Err:1.146 Test-Acc:0.259
#  I:260 Train-Err:0.532 Train-Acc:0.655 Test-Err:1.168 Test-Acc:0.256
#  I:270 Train-Err:0.529 Train-Acc:0.661 Test-Err:1.192 Test-Acc:0.251
#  I:280 Train-Err:0.525 Train-Acc:0.663 Test-Err:1.219 Test-Acc:0.241
#  I:290 Train-Err:0.520 Train-Acc:0.664 Test-Err:1.245 Test-Acc:0.241
#  I:300 Train-Err:0.515 Train-Acc:0.666 Test-Err:1.271 Test-Acc:0.239
#  I:310 Train-Err:0.510 Train-Acc:0.673 Test-Err:1.300 Test-Acc:0.236
#  I:320 Train-Err:0.506 Train-Acc:0.672 Test-Err:1.329 Test-Acc:0.234
#  I:330 Train-Err:0.502 Train-Acc:0.677 Test-Err:1.360 Test-Acc:0.228
#  I:340 Train-Err:0.499 Train-Acc:0.681 Test-Err:1.390 Test-Acc:0.228
#  I:350 Train-Err:0.495 Train-Acc:0.681 Test-Err:1.421 Test-Acc:0.224
#  I:360 Train-Err:0.490 Train-Acc:0.684 Test-Err:1.453 Test-Acc:0.224
#  I:370 Train-Err:0.486 Train-Acc:0.685 Test-Err:1.481 Test-Acc:0.225
#  I:380 Train-Err:0.482 Train-Acc:0.686 Test-Err:1.510 Test-Acc:0.226
#  I:390 Train-Err:0.479 Train-Acc:0.685 Test-Err:1.539 Test-Acc:0.229
#  I:400 Train-Err:0.477 Train-Acc:0.684 Test-Err:1.569 Test-Acc:0.227
#  I:410 Train-Err:0.475 Train-Acc:0.685 Test-Err:1.598 Test-Acc:0.226
#  I:420 Train-Err:0.473 Train-Acc:0.687 Test-Err:1.625 Test-Acc:0.227
#  I:430 Train-Err:0.471 Train-Acc:0.691 Test-Err:1.657 Test-Acc:0.228
#  I:440 Train-Err:0.469 Train-Acc:0.693 Test-Err:1.691 Test-Acc:0.226
#  I:450 Train-Err:0.468 Train-Acc:0.696 Test-Err:1.730 Test-Acc:0.224
#  I:460 Train-Err:0.466 Train-Acc:0.696 Test-Err:1.773 Test-Acc:0.223
#  I:470 Train-Err:0.464 Train-Acc:0.697 Test-Err:1.825 Test-Acc:0.222
#  I:480 Train-Err:0.462 Train-Acc:0.698 Test-Err:1.882 Test-Acc:0.225
#  I:490 Train-Err:0.460 Train-Acc:0.699 Test-Err:1.942 Test-Acc:0.22
#  I:500 Train-Err:0.459 Train-Acc:0.703 Test-Err:2.014 Test-Acc:0.216
#  I:510 Train-Err:0.457 Train-Acc:0.703 Test-Err:2.097 Test-Acc:0.212
#  I:520 Train-Err:0.456 Train-Acc:0.704 Test-Err:2.181 Test-Acc:0.214
#  I:530 Train-Err:0.454 Train-Acc:0.706 Test-Err:2.266 Test-Acc:0.213
#  I:540 Train-Err:0.453 Train-Acc:0.708 Test-Err:2.348 Test-Acc:0.214
#  I:550 Train-Err:0.452 Train-Acc:0.707 Test-Err:2.440 Test-Acc:0.213
#  I:560 Train-Err:0.451 Train-Acc:0.709 Test-Err:2.547 Test-Acc:0.206
#  I:570 Train-Err:0.450 Train-Acc:0.708 Test-Err:2.662 Test-Acc:0.212
#  I:580 Train-Err:0.449 Train-Acc:0.71 Test-Err:2.781 Test-Acc:0.207
#  I:590 Train-Err:0.448 Train-Acc:0.713 Test-Err:2.894 Test-Acc:0.206
#  I:600 Train-Err:0.447 Train-Acc:0.713 Test-Err:3.016 Test-Acc:0.206
#  I:610 Train-Err:0.447 Train-Acc:0.716 Test-Err:3.116 Test-Acc:0.2
#  I:620 Train-Err:0.446 Train-Acc:0.717 Test-Err:3.179 Test-Acc:0.2
#  I:630 Train-Err:0.446 Train-Acc:0.72 Test-Err:3.285 Test-Acc:0.198
#  I:640 Train-Err:0.449 Train-Acc:0.719 Test-Err:3.373 Test-Acc:0.193
#  I:650 Train-Err:0.446 Train-Acc:0.721 Test-Err:3.425 Test-Acc:0.195
#  I:660 Train-Err:0.443 Train-Acc:0.722 Test-Err:3.584 Test-Acc:0.193
#  I:670 Train-Err:0.441 Train-Acc:0.722 Test-Err:3.703 Test-Acc:0.192
#  I:680 Train-Err:0.441 Train-Acc:0.723 Test-Err:3.781 Test-Acc:0.195
#  I:690 Train-Err:0.439 Train-Acc:0.723 Test-Err:3.861 Test-Acc:0.199
#  I:700 Train-Err:0.438 Train-Acc:0.725 Test-Err:3.998 Test-Acc:0.192
#  I:710 Train-Err:0.436 Train-Acc:0.726 Test-Err:4.040 Test-Acc:0.192
#  I:720 Train-Err:0.436 Train-Acc:0.722 Test-Err:4.146 Test-Acc:0.189
#  I:730 Train-Err:0.434 Train-Acc:0.725 Test-Err:4.225 Test-Acc:0.181
#  I:740 Train-Err:0.435 Train-Acc:0.725 Test-Err:4.359 Test-Acc:0.182
#  I:749 Train-Err:0.432 Train-Acc:0.726 Test-Err:4.511 Test-Acc:0.187

# %% [markdown]
# # **Dropout In Code**

# %%
i = 0
layer_0 = images[i:i+1]
dropout_mask = np.random.randint(2,size=layer_1.shape)

layer_1 *= dropout_mask * 2
layer_2 = np.dot(layer_1, weights_1_2)

error += np.sum((labels[i:i+1] - layer_2) ** 2)

correct_cnt += int(np.argmax(layer_2) == np.argmax(labels[i+i+1]))

layer_2_delta = (labels[i:i+1] - layer_2)
layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)

layer_1_delta *= dropout_mask

weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)

# %%
import numpy, sys
np.random.seed(1)
def relu(x):
    return (x >= 0) * x # returns x if x > 0
                        # returns 0 otherwise

def relu2deriv(output):
    return output >= 0 #returns 1 for input > 0

alpha, iterations, hidden_size = (0.005, 750, 100)
pixels_per_image, num_labels = (784, 47)

weights_0_1 = 0.2*np.random.random((pixels_per_image,hidden_size)) - 0.1
weights_1_2 = 0.2*np.random.random((hidden_size,num_labels)) - 0.1

for j in range(iterations):
    error, correct_cnt = (0.0,0)
    for i in range(len(images)):
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0,weights_0_1))
        dropout_mask = np.random.randint(2, size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = np.dot(layer_1,weights_1_2)

        error += np.sum((labels[i:i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == np.argmax(labels[i:i+1]))
        layer_2_delta = (labels[i:i+1] - layer_2)
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)
        layer_1_delta *= dropout_mask

        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)

    if(j%10 == 0):
        test_error = 0.0
        test_correct_cnt = 0

        for i in range(len(test_images)):
            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0,weights_0_1))
            layer_2 = np.dot(layer_1, weights_1_2)

            test_error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
            test_correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))

        sys.stdout.write("\n" + \
                         "I:" + str(j) + \
                         " Test-Err:" + str(test_error/ float(len(test_images)))[0:5] +\
                         " Test-Acc:" + str(test_correct_cnt/ float(len(test_images)))+\
                         " Train-Err:" + str(error/ float(len(images)))[0:5] +\
                         " Train-Acc:" + str(correct_cnt/ float(len(images))))
# Out:
# I:0 Test-Err:1.017 Test-Acc:0.068 Train-Err:1.417 Train-Acc:0.039
# I:10 Test-Err:0.914 Test-Acc:0.214 Train-Err:0.917 Train-Acc:0.235
# I:20 Test-Err:0.884 Test-Acc:0.27 Train-Err:0.871 Train-Acc:0.258
# I:30 Test-Err:0.867 Test-Acc:0.316 Train-Err:0.843 Train-Acc:0.286
# I:40 Test-Err:0.856 Test-Acc:0.321 Train-Err:0.830 Train-Acc:0.306
# I:50 Test-Err:0.851 Test-Acc:0.329 Train-Err:0.826 Train-Acc:0.31
# I:60 Test-Err:0.847 Test-Acc:0.33 Train-Err:0.814 Train-Acc:0.321
# I:70 Test-Err:0.849 Test-Acc:0.32 Train-Err:0.803 Train-Acc:0.321
# I:80 Test-Err:0.851 Test-Acc:0.321 Train-Err:0.807 Train-Acc:0.321
# I:90 Test-Err:0.852 Test-Acc:0.334 Train-Err:0.805 Train-Acc:0.317
# I:100 Test-Err:0.848 Test-Acc:0.337 Train-Err:0.791 Train-Acc:0.34
# I:110 Test-Err:0.852 Test-Acc:0.328 Train-Err:0.781 Train-Acc:0.357
# I:120 Test-Err:0.857 Test-Acc:0.337 Train-Err:0.793 Train-Acc:0.335
# I:130 Test-Err:0.860 Test-Acc:0.321 Train-Err:0.796 Train-Acc:0.321
# I:140 Test-Err:0.862 Test-Acc:0.324 Train-Err:0.812 Train-Acc:0.301
# I:150 Test-Err:0.858 Test-Acc:0.344 Train-Err:0.775 Train-Acc:0.356
# I:160 Test-Err:0.867 Test-Acc:0.324 Train-Err:0.792 Train-Acc:0.329
# I:170 Test-Err:0.865 Test-Acc:0.342 Train-Err:0.792 Train-Acc:0.346
# I:180 Test-Err:0.869 Test-Acc:0.324 Train-Err:0.778 Train-Acc:0.361
# I:190 Test-Err:0.872 Test-Acc:0.323 Train-Err:0.777 Train-Acc:0.361
# I:200 Test-Err:0.876 Test-Acc:0.329 Train-Err:0.768 Train-Acc:0.378
# I:210 Test-Err:0.877 Test-Acc:0.324 Train-Err:0.772 Train-Acc:0.345
# I:220 Test-Err:0.876 Test-Acc:0.325 Train-Err:0.763 Train-Acc:0.358
# I:230 Test-Err:0.883 Test-Acc:0.334 Train-Err:0.755 Train-Acc:0.383
# I:240 Test-Err:0.884 Test-Acc:0.319 Train-Err:0.773 Train-Acc:0.348
# I:250 Test-Err:0.890 Test-Acc:0.313 Train-Err:0.756 Train-Acc:0.365
# I:260 Test-Err:0.889 Test-Acc:0.304 Train-Err:0.768 Train-Acc:0.352
# I:270 Test-Err:0.888 Test-Acc:0.318 Train-Err:0.771 Train-Acc:0.355
# I:280 Test-Err:0.895 Test-Acc:0.303 Train-Err:0.761 Train-Acc:0.364
# I:290 Test-Err:0.900 Test-Acc:0.327 Train-Err:0.759 Train-Acc:0.372
# I:300 Test-Err:0.914 Test-Acc:0.318 Train-Err:0.751 Train-Acc:0.372
# I:310 Test-Err:0.922 Test-Acc:0.321 Train-Err:0.743 Train-Acc:0.379
# I:320 Test-Err:0.923 Test-Acc:0.312 Train-Err:0.760 Train-Acc:0.358
# I:330 Test-Err:0.936 Test-Acc:0.32 Train-Err:0.751 Train-Acc:0.369
# I:340 Test-Err:0.941 Test-Acc:0.316 Train-Err:0.750 Train-Acc:0.381
# I:350 Test-Err:0.953 Test-Acc:0.317 Train-Err:0.757 Train-Acc:0.359
# I:360 Test-Err:0.959 Test-Acc:0.319 Train-Err:0.743 Train-Acc:0.377
# I:370 Test-Err:0.948 Test-Acc:0.309 Train-Err:0.757 Train-Acc:0.359
# I:380 Test-Err:0.965 Test-Acc:0.303 Train-Err:0.737 Train-Acc:0.391
# I:390 Test-Err:0.964 Test-Acc:0.314 Train-Err:0.742 Train-Acc:0.381
# I:400 Test-Err:0.984 Test-Acc:0.317 Train-Err:0.738 Train-Acc:0.395
# I:410 Test-Err:0.988 Test-Acc:0.294 Train-Err:0.755 Train-Acc:0.362
# I:420 Test-Err:0.988 Test-Acc:0.313 Train-Err:0.742 Train-Acc:0.38
# I:430 Test-Err:1.004 Test-Acc:0.304 Train-Err:0.720 Train-Acc:0.408
# I:440 Test-Err:1.024 Test-Acc:0.299 Train-Err:0.750 Train-Acc:0.372
# I:450 Test-Err:1.040 Test-Acc:0.312 Train-Err:0.740 Train-Acc:0.398
# I:460 Test-Err:1.055 Test-Acc:0.291 Train-Err:0.731 Train-Acc:0.396
# I:470 Test-Err:1.061 Test-Acc:0.304 Train-Err:0.729 Train-Acc:0.386
# I:480 Test-Err:1.070 Test-Acc:0.304 Train-Err:0.737 Train-Acc:0.392
# I:490 Test-Err:1.097 Test-Acc:0.312 Train-Err:0.739 Train-Acc:0.386
# I:500 Test-Err:1.106 Test-Acc:0.311 Train-Err:0.742 Train-Acc:0.384
# I:510 Test-Err:1.129 Test-Acc:0.314 Train-Err:0.735 Train-Acc:0.375
# I:520 Test-Err:1.172 Test-Acc:0.323 Train-Err:0.721 Train-Acc:0.387
# I:530 Test-Err:1.185 Test-Acc:0.309 Train-Err:0.718 Train-Acc:0.395
# I:540 Test-Err:1.211 Test-Acc:0.303 Train-Err:0.721 Train-Acc:0.389
# I:550 Test-Err:1.252 Test-Acc:0.306 Train-Err:0.715 Train-Acc:0.402
# I:560 Test-Err:1.304 Test-Acc:0.3 Train-Err:0.717 Train-Acc:0.405
# I:570 Test-Err:1.323 Test-Acc:0.3 Train-Err:0.706 Train-Acc:0.422
# I:580 Test-Err:1.340 Test-Acc:0.3 Train-Err:0.721 Train-Acc:0.397
# I:590 Test-Err:1.389 Test-Acc:0.307 Train-Err:0.716 Train-Acc:0.413
# I:600 Test-Err:1.415 Test-Acc:0.313 Train-Err:0.717 Train-Acc:0.4
# I:610 Test-Err:1.462 Test-Acc:0.317 Train-Err:0.712 Train-Acc:0.417
# I:620 Test-Err:1.524 Test-Acc:0.314 Train-Err:0.720 Train-Acc:0.397
# I:630 Test-Err:1.518 Test-Acc:0.323 Train-Err:0.709 Train-Acc:0.41
# I:640 Test-Err:1.580 Test-Acc:0.315 Train-Err:0.711 Train-Acc:0.412
# I:650 Test-Err:1.640 Test-Acc:0.308 Train-Err:0.718 Train-Acc:0.395
# I:660 Test-Err:1.664 Test-Acc:0.309 Train-Err:0.703 Train-Acc:0.419
# I:670 Test-Err:1.751 Test-Acc:0.309 Train-Err:0.725 Train-Acc:0.394
# I:680 Test-Err:1.764 Test-Acc:0.296 Train-Err:0.706 Train-Acc:0.41
# I:690 Test-Err:1.817 Test-Acc:0.289 Train-Err:0.714 Train-Acc:0.4
# I:700 Test-Err:1.883 Test-Acc:0.322 Train-Err:0.701 Train-Acc:0.415
# I:710 Test-Err:1.946 Test-Acc:0.325 Train-Err:0.708 Train-Acc:0.401
# I:720 Test-Err:2.024 Test-Acc:0.321 Train-Err:0.681 Train-Acc:0.442
# I:730 Test-Err:2.076 Test-Acc:0.312 Train-Err:0.695 Train-Acc:0.429
# I:740 Test-Err:2.165 Test-Acc:0.319 Train-Err:0.689 Train-Acc:0.435

# %% [markdown]
# # **Batch Gradient Descent**

# %%
np.random.seed(1)

def relu(x):
    return (x >= 0) * x # returns x if x > 0

def relu2deriv(output):
    return output >= 0 # returns 1 for input > 0

batch_size = 100
alpha, iterations = (0.001, 300)
pixels_per_image, num_labels, hidden_size = (784, 47, 100)

weights_0_1 = 0.2*np.random.random((pixels_per_image,hidden_size)) - 0.1
weights_1_2 = 0.2*np.random.random((hidden_size,num_labels)) - 0.1

for j in range(iterations):
    error, correct_cnt = (0.0, 0)
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end = ((i * batch_size),((i+1)*batch_size))

        layer_0 = images[batch_start:batch_end]
        layer_1 = relu(np.dot(layer_0,weights_0_1))
        dropout_mask = np.random.randint(2,size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = np.dot(layer_1,weights_1_2)

        error += np.sum((labels[batch_start:batch_end] - layer_2) ** 2)
        for k in range(batch_size):
            correct_cnt += int(np.argmax(layer_2[k:k+1]) == np.argmax(labels[batch_start+k:batch_start+k+1]))

            layer_2_delta = (labels[batch_start:batch_end]-layer_2)/batch_size
            layer_1_delta = layer_2_delta.dot(weights_1_2.T)* relu2deriv(layer_1)
            layer_1_delta *= dropout_mask

            weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
            weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)
            
    if(j%10 == 0):
        test_error = 0.0
        test_correct_cnt = 0

        for i in range(len(test_images)):
            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0,weights_0_1))
            layer_2 = np.dot(layer_1, weights_1_2)

            test_error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
            test_correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))

        sys.stdout.write("\n" + \
                         "I:" + str(j) + \
                         " Test-Err:" + str(test_error/ float(len(test_images)))[0:5] +\
                         " Test-Acc:" + str(test_correct_cnt/ float(len(test_images)))+\
                         " Train-Err:" + str(error/ float(len(images)))[0:5] +\
                         " Train-Acc:" + str(correct_cnt/ float(len(images))))
# Out:
# I:0 Test-Err:1.164 Test-Acc:0.031 Train-Err:2.519 Train-Acc:0.019
# I:10 Test-Err:0.981 Test-Acc:0.137 Train-Err:1.016 Train-Acc:0.121
# I:20 Test-Err:0.957 Test-Acc:0.18 Train-Err:0.974 Train-Acc:0.159
# I:30 Test-Err:0.942 Test-Acc:0.203 Train-Err:0.946 Train-Acc:0.223
# I:40 Test-Err:0.929 Test-Acc:0.224 Train-Err:0.927 Train-Acc:0.235
# I:50 Test-Err:0.916 Test-Acc:0.236 Train-Err:0.915 Train-Acc:0.234
# I:60 Test-Err:0.907 Test-Acc:0.258 Train-Err:0.900 Train-Acc:0.245
# I:70 Test-Err:0.898 Test-Acc:0.266 Train-Err:0.891 Train-Acc:0.27
# I:80 Test-Err:0.893 Test-Acc:0.271 Train-Err:0.880 Train-Acc:0.251
# I:90 Test-Err:0.887 Test-Acc:0.277 Train-Err:0.866 Train-Acc:0.275
# I:100 Test-Err:0.883 Test-Acc:0.291 Train-Err:0.862 Train-Acc:0.291
# I:110 Test-Err:0.877 Test-Acc:0.294 Train-Err:0.853 Train-Acc:0.313
# I:120 Test-Err:0.875 Test-Acc:0.32 Train-Err:0.851 Train-Acc:0.291
# I:130 Test-Err:0.874 Test-Acc:0.316 Train-Err:0.860 Train-Acc:0.263
# I:140 Test-Err:0.870 Test-Acc:0.316 Train-Err:0.849 Train-Acc:0.293
# I:150 Test-Err:0.869 Test-Acc:0.311 Train-Err:0.846 Train-Acc:0.286
# I:160 Test-Err:0.865 Test-Acc:0.307 Train-Err:0.846 Train-Acc:0.279
# I:170 Test-Err:0.866 Test-Acc:0.313 Train-Err:0.835 Train-Acc:0.308
# I:180 Test-Err:0.864 Test-Acc:0.316 Train-Err:0.831 Train-Acc:0.311
# I:190 Test-Err:0.864 Test-Acc:0.312 Train-Err:0.835 Train-Acc:0.294
# I:200 Test-Err:0.861 Test-Acc:0.318 Train-Err:0.825 Train-Acc:0.302
# I:210 Test-Err:0.864 Test-Acc:0.315 Train-Err:0.829 Train-Acc:0.295
# I:220 Test-Err:0.861 Test-Acc:0.323 Train-Err:0.813 Train-Acc:0.331
# I:230 Test-Err:0.859 Test-Acc:0.324 Train-Err:0.822 Train-Acc:0.32
# I:240 Test-Err:0.862 Test-Acc:0.319 Train-Err:0.824 Train-Acc:0.327
# I:250 Test-Err:0.860 Test-Acc:0.315 Train-Err:0.816 Train-Acc:0.314
# I:260 Test-Err:0.862 Test-Acc:0.312 Train-Err:0.831 Train-Acc:0.298
# I:270 Test-Err:0.861 Test-Acc:0.324 Train-Err:0.827 Train-Acc:0.305
# I:280 Test-Err:0.861 Test-Acc:0.326 Train-Err:0.822 Train-Acc:0.323
# I:290 Test-Err:0.860 Test-Acc:0.322 Train-Err:0.821 Train-Acc:0.311
